# %%
# !pip install astroquery
# Out:
# ...
#      |████████████████████████████████| 4.5MB 2.8MB/s
# ...
#      |████████████████████████████████| 2.7MB 37.0MB/s
# ...
#   Created wheel for astroquery: filename=astroquery-0.4-cp36-none-any.whl size=3582510 sha256=0113fde99617ea2b9731acfd11f47945d4338943a665ca3ef75fa691e0bde600
#   Stored in directory: /root/.cache/pip/wheels/a3/6d/9d/f6ceddc68de0e4b7a64b56d6e8c8075e6ef6377ec9c05ce128
# Successfully built astroquery
# ...

# %% [markdown]
# #[REF]https://ssd.jpl.nasa.gov/horizons.cgi
# #[Target]
# 10: Sun 199: Mercury 299: Venus 399: Earth 499: Mars 599: Jupiter
# 699: Saturn 799: Uranus 899: Neptune 999: Pluto
# #[Observer]
# "500" Earth's center (same as "geocentric")
# "@sun" center of the Sun
# "@0" solar system barycenter (same as "@ssb")
# "Viking 1@499" Viking 1 landing site on Mars (body 499)
# "@hst" Hubble Space Telescope (same as "@-48")
# "@-32" Voyager 2 spacecraft
# "@301" center of the Moon
# "Apollo 11@301" Apollo 11 landing site on the Moon's surface
# "@phobos" center of Phobos, the Martian moon (same as "@401")

# %%
from astroquery.jplhorizons import Horizons
obj = Horizons(id='499',location='@phobos',epochs={'start':'2000-10-01', 'stop':'2100-10-10','step':'5d'})
vec = obj.vectors()
x = vec['x']
y = vec['y']
z = vec['z']

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
g = plt.subplot()
#g.scatter(x, y, c=cm.jet(np.abs(z)), edgecolor='none')
g.scatter(x, y, c=cm.Spectral(np.abs(z)), edgecolor='none')
g.set_xlabel('X')
g.set_ylabel('Y')
g.set_title('Title')
g.set_aspect('equal')
plt.savefig('image.png')
plt.show()

# %%
# !pip install chart_studio

# %%
import chart_studio.plotly as py

py.plotly.tools.set_credentials_file(username='bluedack', api_key='6cP0jH8kBYNApA9XBwIS')
py.plotly.tools.set_config_file(world_readable=True, sharing='public')

def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))
  
import numpy as np
from scipy import stats
from plotly.offline import iplot, init_notebook_mode
import plotly.graph_objs as go

configure_plotly_browser_state()
init_notebook_mode(connected=False)

import plotly.express as px

import pandas as pd
import numpy as np

x = np.array(x)
y = np.array(y)
z = np.array(z)

df = pd.DataFrame(np.stack([x, y, z], 1),columns=['x', 'y', 'z'])
fig = px.scatter_3d(df, x='x', y='y', z='z',color='z',color_continuous_scale=["red", "green", "blue", "black"])
fig.show(filename = 'basic-line', auto_open=True, sharing='public')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip install slackweb

# %%
import requests

url = "https://slack.com/api/chat.postMessage"
data = {
   "token": "xoxp-978638733729-988272372164-1053175804726-c28db97f50c73a0f682e64b9edf37f1f",
   "channel": "CUSJSNAP3",
   "text": "Image has been generated @Keiichiro Fujimoto "
}
requests.post(url, data=data)
# Out:
# <Response [200]>

# %%
import requests

url = "https://slack.com/api/files.upload"
data = {
   "token": "xoxp-978638733729-988272372164-1053175804726-c28db97f50c73a0f682e64b9edf37f1f",
   "channel": "CUSJSNAP3",
   "title": "my file",
   "initial_comment": "initial\ncomment"
}
files = {'file': open("image.png", 'rb')}
requests.post(url, data=data, files=files)
# Out:
# <Response [200]>
